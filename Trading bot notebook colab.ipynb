# %% [markdown]
# 1. Обновление списка бумаг и дозагрузка данных, включая ставку ЦБ РФ, курс Доллар/Рубль, цены различных марок нефти, индекс Мосбиржи

# %%
# !python -m _tools.update_universe \
    --min-days 320

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime
from dateutil.relativedelta import relativedelta
from finam_export import Exporter, Market, Timeframe

# --- НАСТРОЙКИ ---
TICKER_TO_DOWNLOAD = "SBER"
YEARS_OF_HISTORY = 20
OUTPUT_DIR = Path("1_data")
# -----------------

# Гарантируем, что папка для данных существует
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
output_path = OUTPUT_DIR / f"{TICKER_TO_DOWNLOAD}_D1_MOEX.csv"

print(f"--- 🚀 Запуск надежной загрузки для тикера: {TICKER_TO_DOWNLOAD} через finam-export ---")

try:
    # --- 1. Определяем даты ---
    end_date = datetime.now().date()
    start_date = (datetime.now() - relativedelta(years=YEARS_OF_HISTORY)).date()
    
    print(f"Запрашиваемый период: с {start_date} по {end_date}.")

    # --- 2. Загрузка данных с помощью finam-export ---
    exporter = Exporter()
    # Ищем SBER на рынке акций MOEX
    sber = exporter.lookup(name=TICKER_TO_DOWNLOAD, market=Market.STOCKS)
    
    if not sber.empty:
        # Получаем ID тикера для запроса
        sber_id = sber.index[0]
        data = exporter.download(
            sber_id,
            market=Market.STOCKS,
            start_date=start_date,
            end_date=end_date,
            timeframe=Timeframe.DAILY
        )
    else:
        raise ValueError(f"Тикер {TICKER_TO_DOWNLOAD} не найден в справочнике Finam.")

    # --- 3. Форматирование и сохранение ---
    if not data.empty:
        # Переименовываем колонки в ваш формат
        # Finam использует <DATE>, <OPEN>, <HIGH>, <LOW>, <CLOSE>, <VOL>
        rename_map = {
            '<DATE>': 'datetime',
            '<OPEN>': 'open',
            '<HIGH>': 'high',
            '<LOW>': 'low',
            '<CLOSE>': 'close',
            '<VOL>': 'volume'
        }
        data.rename(columns=rename_map, inplace=True)
        
        # Преобразуем дату
        data['datetime'] = pd.to_datetime(data['datetime'], format='%Y%m%d')
        
        # Оставляем только нужные колонки
        final_df = data[list(rename_map.values())].copy()
        
        # Сортируем на всякий случай
        final_df.sort_values('datetime', inplace=True)
        
        # Сохраняем файл, полностью перезаписывая старый
        final_df.to_csv(output_path, index=False)

        print(f"\n--- 📊 Итоги загрузки ---")
        print(f"✅ Успешно сохранено {len(final_df)} строк.")
        print(f"  - Первая дата в файле: {final_df['datetime'].min().date()}")
        print(f"  - Последняя дата в файле: {final_df['datetime'].max().date()}")
        print(f"Файл сохранен в: {output_path}")

    else:
        print("⚠️ finam-export не вернул данные.")

except Exception as e:
    print(f"\n❌ Произошла ошибка при загрузке через finam-export: {e}")
# Out:
# --- 🚀 Запуск надежной загрузки для тикера: SBER через CLI finam-export ---
# Запрашиваемый период: с 2005-10-16 по 2025-10-16.
#
# Выполняю команду:
# /home/restorator/trader_test/.venv-tf/bin/python -m finam_export SBER 1_data/SBER_D1_MOEX.csv --start-date 20051016 --end-date 20251016 --market shares --timeframe daily
#
# --- ❌ Ошибка выполнения finam-export ---
# /home/restorator/trader_test/.venv-tf/bin/python: No module named finam_export
#
#
# ❌ Произошла непредвиденная ошибка: CLI finam-export завершился с ошибкой.

# %%
import sys
# !{sys.executable} -m pip install finam-export
# Out:
# Requirement already satisfied: finam-export in ./.venv-tf/lib/python3.12/site-packages (5.1.1)
# Requirement already satisfied: pandas>=1.1.2 in ./.venv-tf/lib/python3.12/site-packages (from finam-export) (2.3.2)
# Requirement already satisfied: requests<3,>=2.24.0 in ./.venv-tf/lib/python3.12/site-packages (from finam-export) (2.32.5)
# Requirement already satisfied: enum34 in ./.venv-tf/lib/python3.12/site-packages (from finam-export) (1.1.10)
# Requirement already satisfied: click>=7.1.2 in ./.venv-tf/lib/python3.12/site-packages (from finam-export) (8.3.0)
# Requirement already satisfied: click-datetime>=0.2 in ./.venv-tf/lib/python3.12/site-packages (from finam-export) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv-tf/lib/python3.12/site-packages (from requests<3,>=2.24.0->finam-export) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv-tf/lib/python3.12/site-packages (from requests<3,>=2.24.0->finam-export) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv-tf/lib/python3.12/site-packages (from requests<3,>=2.24.0->finam-export) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv-tf/lib/python3.12/site-packages (from requests<3,>=2.24.0->finam-export) (2025.8.3)
# Requirement already satisfied: wheel<0.45.0,>=0.44.0 in ./.venv-tf/lib/python3.12/site-packages (from click-datetime>=0.2->finam-export) (0.44.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv-tf/lib/python3.12/site-packages (from pandas>=1.1.2->finam-export) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv-tf/lib/python3.12/site-packages (from pandas>=1.1.2->finam-export) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv-tf/lib/python3.12/site-packages (from pandas>=1.1.2->finam-export) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv-tf/lib/python3.12/site-packages (from pandas>=1.1.2->finam-export) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv-tf/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.2->finam-export) (1.17.0)

# %%
# !python -m _tools.download_all_data
# !python -m _tools.analyze_data_coverage
# Out:
# --- Начинаю полную загрузку данных за 20 лет ---
#
# [1/7] Загрузка котировок по акциям...
# Загрузка акций: 100%|█████████████████████████| 243/243 [05:09<00:00,  1.27s/it]
# ✅ Загрузка акций завершена.
#    - Новых файлов создано: 243
#    - Файлов обновлено: 0
#    - Актуальных файлов (без изменений): 0
#    - Ошибок: 0
#
# [2/7] Загрузка индексов МосБиржи (IMOEX/MOEXBC)...
# Загрузка истории индекса IMOEX с 2005-10-15...
# ✅ Полная история индекса IMOEX (5010 строк) сохранена в 1_data/IMOEX.csv
#
# [3/7] Загрузка ключевой ставки ЦБ РФ...
# Загрузка полной истории ключевой ставки со страницы: https://www.cbr.ru/hd_base/keyrate/...
# ✅ Полная история ключевой ставки успешно сохранена в /home/restorator/trader_test/1_data/CBR_KEY_RATE.csv
#
# [4/7] Загрузка истории официального курса USD/RUB от ЦБ РФ...
# Загрузка истории USD/RUB с сайта ЦБ РФ (15/10/2005 - 15/10/2025)...
# ✅ Полная история USD/RUB (7306 строк) сохранена в /home/restorator/trader_test/1_data/USDRUB.csv
#
# [5/7] Загрузка истории нефти Brent (BZ=F)...
# Загрузка истории для 'BZ=F' с 2005-10-15...
# ✅ История 'BZ=F' (6653 строк) сохранена в /home/restorator/trader_test/1_data/BRENT.csv
#
# [6/7] Загрузка истории индекса S&P 500 (^GSPC)...
# Загрузка истории для '^GSPC' с 2005-10-15...
# ✅ История '^GSPC' (7304 строк) сохранена в /home/restorator/trader_test/1_data/SP500.csv
#
# [7/7] Загрузка истории индекса VIX (^VIX)...
# Загрузка истории для '^VIX' с 2005-10-15...
# ✅ История '^VIX' (7304 строк) сохранена в /home/restorator/trader_test/1_data/VIX.csv
#
# --- ✅ Все данные успешно загружены и обновлены ---
# --- 🔬 Анализ временного покрытия скачанных данных ---
# Найдено 243 тикеров в файле universe.csv
# Анализ файлов: 100%|█████████████████████████| 243/243 [00:02<00:00, 116.35it/s]
#
# Создание гистограммы распределения...
# ✅ Гистограмма сохранена в: /home/restorator/trader_test/2_results/reports/data_coverage_histogram.png
#
# ==================================================
# --- 📊 Итоги анализа ---
#
# Полный CSV отчет сохранен в файл: /home/restorator/trader_test/2_results/reports/data_coverage_report.csv
# ==================================================

# %% [markdown]
# apply_splits теперь находит все сплиты, но допускает ошибки при применении масштабирования, например он пропусти 3 дня для

# %%
# !python -m _tools.apply_splits \
    --data-dir 1_data \
    --workers 8

# %% [markdown]
# 2. Очистка бумаг, обрезая по 2 дня около длинных разрывов, с минимальным сегментом ≥5 дней:

# %%
# !python -m _tools.clean_timeseries \
    --data-dir 1_data \
    --gap-ok 3 \
    --gap-buffer 2 \
    --min-seg-len 5 \
    --inplace \
    --remove-outliers \
    --outlier-abs-threshold 40.0 \
    --outlier-sma-window 20 \
    --outlier-sma-multiplier 9.0
# Out:
# Cleaning OHLCV: 100%|█████████████████████████| 249/249 [00:04<00:00, 61.72it/s]
#
# [OK] Очистка завершена.

# %% [markdown]
# 3. Проверка списка признаков и генерация таблиц с ними на основании загруженных данных

# %%
# !python -m _core.feature_generator

# %% [markdown]
# 4. Оценка матожидания отклонения цены через выбранное количество дней на исторических данных, разметка данных с учетом отклонений

# %% [markdown]
# 5. Ранжированмие признаков, корреляционная фильтрация, отсеивание списка N лучших

# %%
# !python -m _tools.generate_features --workers 7

# %%
# !python -m _tools.analyze_volatility_for_labeling \
    --horizon 10

# %%
# !python -m _tools.labeler \
    --horizon 10 \
    --tp 7.0 \
    --sl 4.5 \
    --workers 7
# Out:
# --- Шаг 2.5: Разметка данных методом 'Тройной преграды' ---
# Параметры: Горизонт=10 дней, TakeProfit=7.0%, StopLoss=4.5%
# Найдено 243 файлов для обработки. Запускаю в 7 потоков...
# Разметка файлов: 100%|████████████████████████| 243/243 [00:09<00:00, 25.30it/s]
#
# ✅ Процесс разметки завершен.
# 🎉 Все файлы обработаны без ошибок.
# Обработанные файлы сохранены в: /home/restorator/trader_test/2_results/features_processed

# %%
MODEL_NAME="universal_60_10_v1_corr_threshold_100"
DATA_SOURCE_MODEL="universal_60_10_v1_corr_threshold_100"
MODEL_NAME_PREFIX="universal_60_10_v1"
UNIVERSE_FILE="universe.csv"

# %%
# !python -m _tools.feature_selector \
    --model_name "{MODEL_NAME}" \
    --top_n 160 \
    --corr_threshold 1.00 \
    --repeats 3 \
    --n_splits 5 \
    --use_gpu
# Out:
# Загрузка файлов с признаками из: /home/restorator/trader_test/2_results/features_processed
# Загрузка файлов с признаками: 100%|███████████| 243/243 [00:04<00:00, 49.08it/s]
# Заполнение пропусков: 100%|█████████████████| 149/149 [00:00<00:00, 2230.18it/s]
#
# --- 🚀 Запуск отбора признаков по метрике: 'ACCURACY' ---
#
# --- Повтор [1/3] ---
#   Фолд [1/5]...
#   Фолд [2/5]...
#   Фолд [3/5]...
#   Фолд [4/5]...
#   Фолд [5/5]...
#
# --- Повтор [2/3] ---
#   Фолд [1/5]...
#   Фолд [2/5]...
#   Фолд [3/5]...
#   Фолд [4/5]...
#   Фолд [5/5]...
#
# --- Повтор [3/3] ---
#   Фолд [1/5]...
#   Фолд [2/5]...
#   Фолд [3/5]...
#   Фолд [4/5]...
#   Фолд [5/5]...
#
# --- Рейтинг признаков по ВЛИЯНИЮ НА ТОЧНОСТЬ (положительные = полезные) ---
# Порог корреляции >= 1.0, фильтрация пропускается.
#
# --- Итоговый рейтинг (топ-20) ---
# ICS_26                   0.047060
# imoex_volatility_20d     0.031529
# sp500_close              0.023719
# imoex_close              0.021791
# usdrub_close             0.015392
# usdrub_volatility_20d    0.012368
# VWAP_D                   0.011251
# spread_hl                0.008010
# index                    0.007703
# vix_close                0.006682
# brent_close              0.006409
# month_cos                0.006408
# month                    0.004793
# ROC_60                   0.003923
# BBB_5_2.0_2.0            0.003845
# vix_roc_5d               0.003828
# usdrub_return_5d         0.003044
# OBV                      0.002581
# price_to_range_50d       0.002215
# cbr_rate_close           0.002082
#
# ✅ Список из 149 признаков сохранен в: /home/restorator/trader_test/2_results/selected_features_universal_60_10_v1_corr_threshold_100.json

# %% [markdown]
# 6. Разделение данных train dataset и test dataset. В проверочный набор данных входят последние года всех бумаг

# %%
# !python -m _tools.assemble_final_data \
    --model_name "{MODEL_NAME}" \
    --source_dir_name 'features_processed' \
    --workers 7
    #--source_dir_name 'features_combined/{MODEL_NAME}' \
# Out:
# --- ⚙️ Запуск сборки финального датасета ---
# Источник файлов с признаками: /home/restorator/trader_test/2_results/features_processed
# Загружено 149 отобранных признаков.
# Загрузка и объединение 243 файлов в 7 потоков...
# 100%|████████████████████████████████████████| 243/243 [00:01<00:00, 158.84it/s]
# ✅ Сборка завершена. В итоговой таблице 152 колонок (149 признаков).
# Точка разделения train/test: 2024-10-03
# Иммутация NaN завершена. NaN в train: 117315 → 0; NaN в test: 11520 → 0
#
# ✅ Обучающий набор сохранен в: /home/restorator/trader_test/2_results/final_for_model/universal_60_10_v1_corr_threshold_100/train_final.csv
# ✅ Тестовый набор сохранен в: /home/restorator/trader_test/2_results/final_for_model/universal_60_10_v1_corr_threshold_100/test_final.csv

# %% [markdown]
# 7. Обучение скелера для приведения данных к одному масштабу. Скейлер обучается только на train dataset

# %%
# !python -m _tools.fit_scaler \
    --model_name "{MODEL_NAME}"
# !python -m _tools.apply_scaler \
    --model_name "{MODEL_NAME}"
# Out:
# ————————————————————————————————————————————————————————————
# 🧰 Обучение скейлера (Imputer + RobustScaler)
# Модель: universal_60_10_v1_corr_threshold_100
# Загрузка тренировочных данных из: /home/restorator/trader_test/2_results/final_for_model/universal_60_10_v1_corr_threshold_100/train_final.csv
# ————————————————————————————————————————————————————————————
# Признаков: 149, обучающих сэмплов: 218232
# Обучение Pipeline (Imputer + RobustScaler)...
# ✅ Pipeline успешно обучен.
# ✅ Абсолютно 'безопасный' Pipeline сохранен в: /home/restorator/trader_test/2_results/scalers/universal_60_10_v1_corr_threshold_100_scaler.pkl
# 🗂  Порядок признаков сохранен в: /home/restorator/trader_test/2_results/scalers/universal_60_10_v1_corr_threshold_100_features.json
# Готово.
# ---  Applying Scaler for model: universal_60_10_v1_corr_threshold_100 ---
# Loading artifacts and data...
# Applying scaler transformation...
# Saving scaled data...
# ✅ Scaled data saved to: /home/restorator/trader_test/2_results/features_scaled/universal_60_10_v1_corr_threshold_100

# %% [markdown]
# 8. Конвертация данных в tfrecord формат данных для TensorFlow

# %%
# !python -m _tools.convert_to_tfrecord \
    --model_name "{MODEL_NAME}" \
    --lookback 60
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760475656.575435 1132461 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760475657.917199 1132461 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# --- Converting scaled data to TFRecord for model: universal_60_10_v1_corr_threshold_100 ---
# Loading scaled data...
# Writing train.tfrecord: 100%|█████████████████| 243/243 [02:00<00:00,  2.02it/s]
# Writing test.tfrecord: 100%|██████████████████| 242/242 [00:16<00:00, 15.01it/s]
# Calculating class weights and saving metadata...
# ✅ TFRecord files and metadata saved to: /home/restorator/trader_test/2_results/tfrecord_universal_60_10_v1_corr_threshold_100

# %% [markdown]
# 9. Обучение модели

# %%
MODEL_NAME="universal_60_10_v1_corr_threshold_100"
DATA_SOURCE_MODEL="universal_60_10_v1_corr_threshold_100"
MODEL_NAME_PREFIX="universal_60_10_v1"
UNIVERSE_FILE="universe.csv"

# %%
# !python -m _tools.hyperparameter_tuner \
    --model_name "{MODEL_NAME}" \
    --n_trials 600 \
    --batch_size 4098
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760558637.028696    3704 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760558639.168767    3704 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# [I 2025-10-15 23:04:03,791] A new study created in memory with name: universal_60_10_v1_corr_threshold_100

# %%
# !python -m _tools.train_universal_lstm \
    --model_name "{MODEL_NAME}" \
    --data_model_name "{DATA_SOURCE_MODEL}" \
    --params_from_tuner \
    --params_file "best_params_{MODEL_NAME}.json" \
    --runs 50 \
    --batch_size 4096 \
    --verbose 1
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760545698.563344  790164 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760545700.309550  790164 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Использую данные от модели: 'universal_60_10_v1_corr_threshold_75'
# Обученная модель будет сохранена как: 'universal_60_10_v1_corr_threshold_75'
# ✅ Метаданные загружены.
#
# ---  режим '--params_from_tuner' ---
# Использую указанный файл с параметрами: /home/restorator/trader_test/2_results/best_params_universal_60_10_v1_corr_threshold_75_3.json
# ✅ Лучшие параметры успешно загружены.
# {
#   "conv_filters": 24,
#   "kernel_size": 3,
#   "gru_units_1": 10,
#   "gru_units_2": 8,
#   "dense_units": 32,
#   "dropout_conv": 0.11182142036201763,
#   "dropout_gru": 0.18853699587060285,
#   "l2_reg": 2.1566490590982554e-06,
#   "lrelu_neg_slope": 0.2940014743304041,
#   "lr": 0.004823933078963258
# }
#
# Загружаю датасеты TFRecord...
# ✅ Датасеты TFRecord готовы.
# Текущий глобальный рекорд val_accuracy: 0.00000
# --- Запуск 50 независимых сеансов обучения ---
#
# ========================= Начинаю запуск №1/50 =========================
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 60, 85)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 60, 24)    │      6,144 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 60, 24)    │         48 │ conv1d[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 60, 24)    │          0 │ layer_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 60, 24)    │          0 │ leaky_re_lu[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 60, 20)    │      2,160 │ dropout[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 60, 20)    │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 60, 16)    │      1,440 │ dropout_1[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 60, 16)    │          0 │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 60, 16)    │          0 │ dropout_2[0][0],  │
# │ (Attention)         │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 60, 16)    │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 16)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │        544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 32)        │          0 │ dense[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32)        │          0 │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │         99 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,467 (40.89 KB)
#  Trainable params: 10,467 (40.89 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 325ms/step - accuracy: 0.4297 - loss: 1.0698 - val_accuracy: 0.4087 - val_loss: 1.1215
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.4846 - loss: 1.0098 - val_accuracy: 0.4166 - val_loss: 1.0737
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5061 - loss: 0.9747 - val_accuracy: 0.4361 - val_loss: 1.0454
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5148 - loss: 0.9652 - val_accuracy: 0.4578 - val_loss: 1.0270
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.5222 - loss: 0.9565 - val_accuracy: 0.4651 - val_loss: 1.0196
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.5292 - loss: 0.9474 - val_accuracy: 0.4729 - val_loss: 1.0117
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.5349 - loss: 0.9402 - val_accuracy: 0.4697 - val_loss: 1.0221
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.5377 - loss: 0.9332 - val_accuracy: 0.4718 - val_loss: 1.0145
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.5429 - loss: 0.9252 - val_accuracy: 0.4684 - val_loss: 1.0246
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 232ms/step - accuracy: 0.5490 - loss: 0.9184 - val_accuracy: 0.4675 - val_loss: 1.0362
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.5520 - loss: 0.9108 - val_accuracy: 0.4539 - val_loss: 1.0485
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5609 - loss: 0.8981
# Epoch 12: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #6...
# Epoch 12: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.5507 - loss: 0.9147 - val_accuracy: 0.4417 - val_loss: 1.0836
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.5365 - loss: 0.9367 - val_accuracy: 0.4864 - val_loss: 1.0292
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.5377 - loss: 0.9349 - val_accuracy: 0.4879 - val_loss: 1.0264
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.5393 - loss: 0.9321 - val_accuracy: 0.4881 - val_loss: 1.0306
# Epoch 16/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.5419 - loss: 0.9303 - val_accuracy: 0.4895 - val_loss: 1.0288
# Epoch 17/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.5422 - loss: 0.9276 - val_accuracy: 0.4914 - val_loss: 1.0299
# Epoch 18/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5496 - loss: 0.9095
# Epoch 18: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #6...
# Epoch 18: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.5445 - loss: 0.9253 - val_accuracy: 0.4927 - val_loss: 1.0309
# Epoch 19/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.5358 - loss: 0.9372 - val_accuracy: 0.4878 - val_loss: 1.0275
# Epoch 20/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5384 - loss: 0.9345 - val_accuracy: 0.4890 - val_loss: 1.0269
# Epoch 21/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.5389 - loss: 0.9324 - val_accuracy: 0.4876 - val_loss: 1.0290
# Epoch 21: early stopping
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 1 ---
#   Лучшая val_accuracy этого запуска: 0.47294
# 🏆 Новый ГЛОБАЛЬНЫЙ рекорд! (0.47294 > 0.00000).
#
# ========================= Начинаю запуск №2/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.4356 - loss: 1.0761 - val_accuracy: 0.4758 - val_loss: 1.1635
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.4966 - loss: 1.0105 - val_accuracy: 0.4914 - val_loss: 1.0782
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.5121 - loss: 0.9784 - val_accuracy: 0.4882 - val_loss: 1.0344
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5214 - loss: 0.9613 - val_accuracy: 0.4845 - val_loss: 1.0407
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.5276 - loss: 0.9525 - val_accuracy: 0.4941 - val_loss: 1.0246
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5330 - loss: 0.9403 - val_accuracy: 0.4972 - val_loss: 1.0077
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5397 - loss: 0.9324 - val_accuracy: 0.4901 - val_loss: 1.0027
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.5454 - loss: 0.9265 - val_accuracy: 0.4883 - val_loss: 1.0019
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.5518 - loss: 0.9146 - val_accuracy: 0.4796 - val_loss: 1.0158
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5549 - loss: 0.9087 - val_accuracy: 0.4863 - val_loss: 1.0066
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5569 - loss: 0.9045 - val_accuracy: 0.4830 - val_loss: 1.0140
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5613 - loss: 0.8979 - val_accuracy: 0.4626 - val_loss: 1.0293
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5647 - loss: 0.8925 - val_accuracy: 0.4379 - val_loss: 1.0558
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5760 - loss: 0.8811
# Epoch 14: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #8...
# Epoch 14: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5653 - loss: 0.8941 - val_accuracy: 0.4329 - val_loss: 1.0676
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.5530 - loss: 0.9117 - val_accuracy: 0.5031 - val_loss: 0.9960
# Epoch 16/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5543 - loss: 0.9104 - val_accuracy: 0.5046 - val_loss: 0.9948
# Epoch 17/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5555 - loss: 0.9073 - val_accuracy: 0.5045 - val_loss: 0.9937
# Epoch 18/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5569 - loss: 0.9047 - val_accuracy: 0.5063 - val_loss: 0.9922
# Epoch 19/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.5589 - loss: 0.9022 - val_accuracy: 0.5088 - val_loss: 0.9916
# Epoch 20/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5608 - loss: 0.8998 - val_accuracy: 0.5053 - val_loss: 0.9936
# Epoch 21/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.5616 - loss: 0.8968 - val_accuracy: 0.5060 - val_loss: 0.9939
# Epoch 22/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.5623 - loss: 0.8950 - val_accuracy: 0.5011 - val_loss: 0.9993
# Epoch 23/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5638 - loss: 0.8923 - val_accuracy: 0.4964 - val_loss: 1.0037
# Epoch 24/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.5659 - loss: 0.8906 - val_accuracy: 0.4916 - val_loss: 1.0102
# Epoch 25/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5758 - loss: 0.8718
# Epoch 25: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #19...
# Epoch 25: Снижаю скорость обучения до 2e-04.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5684 - loss: 0.8879 - val_accuracy: 0.4842 - val_loss: 1.0193
# Epoch 26/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5618 - loss: 0.8977 - val_accuracy: 0.5120 - val_loss: 0.9891
# Epoch 27/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.5641 - loss: 0.8959 - val_accuracy: 0.5129 - val_loss: 0.9895
# Epoch 28/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5638 - loss: 0.8948 - val_accuracy: 0.5132 - val_loss: 0.9898
# Epoch 29/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.5634 - loss: 0.8942 - val_accuracy: 0.5121 - val_loss: 0.9901
# Epoch 30/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.5645 - loss: 0.8934 - val_accuracy: 0.5111 - val_loss: 0.9906
# Epoch 31/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5648 - loss: 0.8935 - val_accuracy: 0.5112 - val_loss: 0.9908
# Epoch 32/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5718 - loss: 0.8764
# Epoch 32: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #26...
# Epoch 32: Снижаю скорость обучения до 4e-05.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5646 - loss: 0.8926 - val_accuracy: 0.5105 - val_loss: 0.9918
# Epoch 33/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.5635 - loss: 0.8956 - val_accuracy: 0.5120 - val_loss: 0.9890
# Epoch 34/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5634 - loss: 0.8953 - val_accuracy: 0.5120 - val_loss: 0.9891
# Epoch 35/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5631 - loss: 0.8950 - val_accuracy: 0.5122 - val_loss: 0.9892
# Epoch 36/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.5637 - loss: 0.8952 - val_accuracy: 0.5122 - val_loss: 0.9894
# Epoch 37/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.5635 - loss: 0.8952 - val_accuracy: 0.5118 - val_loss: 0.9895
# Epoch 38/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5715 - loss: 0.8783
# Epoch 38: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #26...
# Epoch 38: Снижаю скорость обучения до 8e-06.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5628 - loss: 0.8947 - val_accuracy: 0.5119 - val_loss: 0.9896
# Epoch 39/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.5633 - loss: 0.8953 - val_accuracy: 0.5121 - val_loss: 0.9891
# Epoch 40/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.5627 - loss: 0.8953 - val_accuracy: 0.5121 - val_loss: 0.9890
# Epoch 41/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5642 - loss: 0.8953 - val_accuracy: 0.5120 - val_loss: 0.9891
# Epoch 42/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5636 - loss: 0.8950 - val_accuracy: 0.5118 - val_loss: 0.9892
# Epoch 43/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5637 - loss: 0.8951 - val_accuracy: 0.5118 - val_loss: 0.9892
# Epoch 44/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5716 - loss: 0.8801
# Epoch 44: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #26...
# Epoch 44: Снижаю скорость обучения до 8e-06.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5639 - loss: 0.8956 - val_accuracy: 0.5120 - val_loss: 0.9892
# Epoch 45/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.5639 - loss: 0.8948 - val_accuracy: 0.5120 - val_loss: 0.9890
# Epoch 46/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5637 - loss: 0.8950 - val_accuracy: 0.5118 - val_loss: 0.9891
# Epoch 47/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5642 - loss: 0.8953 - val_accuracy: 0.5118 - val_loss: 0.9891
# Epoch 48/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5631 - loss: 0.8950 - val_accuracy: 0.5118 - val_loss: 0.9892
# Epoch 48: early stopping
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 2 ---
#   Лучшая val_accuracy этого запуска: 0.51204
# 🏆 Новый ГЛОБАЛЬНЫЙ рекорд! (0.51204 > 0.47294).
#
# ========================= Начинаю запуск №3/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - accuracy: 0.4340 - loss: 1.0647 - val_accuracy: 0.4482 - val_loss: 1.0913
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.4880 - loss: 1.0153 - val_accuracy: 0.4914 - val_loss: 1.0639
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.5022 - loss: 0.9838 - val_accuracy: 0.4947 - val_loss: 1.0053
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5174 - loss: 0.9614 - val_accuracy: 0.4878 - val_loss: 1.0023
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5246 - loss: 0.9502 - val_accuracy: 0.4842 - val_loss: 1.0056
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5310 - loss: 0.9427 - val_accuracy: 0.4773 - val_loss: 1.0082
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.5370 - loss: 0.9335 - val_accuracy: 0.4862 - val_loss: 1.0032
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5427 - loss: 0.9244 - val_accuracy: 0.4749 - val_loss: 1.0112
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5480 - loss: 0.9210 - val_accuracy: 0.4510 - val_loss: 1.0376
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5578 - loss: 0.8976
# Epoch 10: Лучшая точность этого запуска (0.4947) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5513 - loss: 0.9132 - val_accuracy: 0.4316 - val_loss: 1.0538
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 3 ---
#   Лучшая val_accuracy этого запуска: 0.48775
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №4/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 109ms/step - accuracy: 0.4262 - loss: 1.0633 - val_accuracy: 0.4419 - val_loss: 1.1102
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.4893 - loss: 0.9916 - val_accuracy: 0.4895 - val_loss: 1.0423
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5093 - loss: 0.9738 - val_accuracy: 0.4915 - val_loss: 1.0246
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.5172 - loss: 0.9600 - val_accuracy: 0.5003 - val_loss: 1.0087
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5254 - loss: 0.9498 - val_accuracy: 0.4927 - val_loss: 1.0133
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.5323 - loss: 0.9398 - val_accuracy: 0.4679 - val_loss: 1.0209
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5402 - loss: 0.9306 - val_accuracy: 0.4562 - val_loss: 1.0422
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 163ms/step - accuracy: 0.5395 - loss: 0.9299 - val_accuracy: 0.4606 - val_loss: 1.0558
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5449 - loss: 0.9198 - val_accuracy: 0.4389 - val_loss: 1.0825
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5584 - loss: 0.8936
# Epoch 10: Лучшая точность этого запуска (0.5003) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5495 - loss: 0.9094 - val_accuracy: 0.4336 - val_loss: 1.0817
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 4 ---
#   Лучшая val_accuracy этого запуска: 0.50031
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №5/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - accuracy: 0.4207 - loss: 1.0718 - val_accuracy: 0.3667 - val_loss: 1.0886
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.4794 - loss: 1.0047 - val_accuracy: 0.4739 - val_loss: 1.0503
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - accuracy: 0.5047 - loss: 0.9742 - val_accuracy: 0.5000 - val_loss: 1.0214
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5167 - loss: 0.9635 - val_accuracy: 0.4869 - val_loss: 1.0189
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5250 - loss: 0.9560 - val_accuracy: 0.4905 - val_loss: 1.0148
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5321 - loss: 0.9446 - val_accuracy: 0.4796 - val_loss: 1.0145
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5365 - loss: 0.9359 - val_accuracy: 0.4840 - val_loss: 1.0090
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5442 - loss: 0.9218 - val_accuracy: 0.4995 - val_loss: 1.0092
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.5500 - loss: 0.9141 - val_accuracy: 0.4759 - val_loss: 1.0376
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5553 - loss: 0.9068 - val_accuracy: 0.4636 - val_loss: 1.0699
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5604 - loss: 0.8985 - val_accuracy: 0.4468 - val_loss: 1.0915
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5640 - loss: 0.8923 - val_accuracy: 0.4377 - val_loss: 1.1122
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5757 - loss: 0.8717
# Epoch 13: Лучшая точность этого запуска (0.5000) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5681 - loss: 0.8882 - val_accuracy: 0.4334 - val_loss: 1.1208
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 5 ---
#   Лучшая val_accuracy этого запуска: 0.48400
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №6/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.4349 - loss: 1.0688 - val_accuracy: 0.4313 - val_loss: 1.1154
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.4896 - loss: 1.0169 - val_accuracy: 0.4810 - val_loss: 1.0732
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5084 - loss: 0.9817 - val_accuracy: 0.4890 - val_loss: 1.0223
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5167 - loss: 0.9673 - val_accuracy: 0.4812 - val_loss: 1.0149
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5225 - loss: 0.9588 - val_accuracy: 0.4887 - val_loss: 1.0093
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.5277 - loss: 0.9508 - val_accuracy: 0.4861 - val_loss: 1.0091
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5324 - loss: 0.9422 - val_accuracy: 0.4740 - val_loss: 1.0132
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.5384 - loss: 0.9325 - val_accuracy: 0.4834 - val_loss: 1.0119
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.5411 - loss: 0.9283 - val_accuracy: 0.4697 - val_loss: 1.0289
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5452 - loss: 0.9214 - val_accuracy: 0.4797 - val_loss: 1.0362
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5486 - loss: 0.9157 - val_accuracy: 0.4821 - val_loss: 1.0268
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5591 - loss: 0.8917
# Epoch 12: Лучшая точность этого запуска (0.4902) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.5503 - loss: 0.9079 - val_accuracy: 0.4902 - val_loss: 1.0323
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 6 ---
#   Лучшая val_accuracy этого запуска: 0.48612
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №7/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 0.4331 - loss: 1.0648 - val_accuracy: 0.4776 - val_loss: 1.0804
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.4882 - loss: 1.0039 - val_accuracy: 0.4748 - val_loss: 1.0787
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5041 - loss: 0.9778 - val_accuracy: 0.4797 - val_loss: 1.0398
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5093 - loss: 0.9667 - val_accuracy: 0.4830 - val_loss: 1.0305
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.5160 - loss: 0.9626 - val_accuracy: 0.4901 - val_loss: 1.0266
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5220 - loss: 0.9567 - val_accuracy: 0.4961 - val_loss: 1.0194
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5248 - loss: 0.9511 - val_accuracy: 0.4966 - val_loss: 1.0110
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5309 - loss: 0.9434 - val_accuracy: 0.5000 - val_loss: 1.0035
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5374 - loss: 0.9364 - val_accuracy: 0.4926 - val_loss: 1.0025
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5427 - loss: 0.9289 - val_accuracy: 0.4948 - val_loss: 1.0020
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.5489 - loss: 0.9209 - val_accuracy: 0.4872 - val_loss: 1.0108
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5549 - loss: 0.9116 - val_accuracy: 0.4895 - val_loss: 1.0155
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5590 - loss: 0.9060 - val_accuracy: 0.4761 - val_loss: 1.0320
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5639 - loss: 0.8984 - val_accuracy: 0.4586 - val_loss: 1.0650
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5633 - loss: 0.8982 - val_accuracy: 0.4457 - val_loss: 1.0709
# Epoch 16/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5791 - loss: 0.8747
# Epoch 16: Лучшая точность этого запуска (0.5000) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5697 - loss: 0.8912 - val_accuracy: 0.4494 - val_loss: 1.0836
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 7 ---
#   Лучшая val_accuracy этого запуска: 0.49483
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №8/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.4437 - loss: 1.0576 - val_accuracy: 0.4873 - val_loss: 1.0786
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.4937 - loss: 1.0043 - val_accuracy: 0.4904 - val_loss: 1.0369
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5076 - loss: 0.9769 - val_accuracy: 0.4803 - val_loss: 1.0191
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.5169 - loss: 0.9609 - val_accuracy: 0.4963 - val_loss: 1.0077
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - accuracy: 0.5248 - loss: 0.9543 - val_accuracy: 0.4937 - val_loss: 1.0064
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5299 - loss: 0.9448 - val_accuracy: 0.4843 - val_loss: 1.0107
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5355 - loss: 0.9337 - val_accuracy: 0.4878 - val_loss: 1.0146
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5439 - loss: 0.9225 - val_accuracy: 0.4749 - val_loss: 1.0360
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - accuracy: 0.5459 - loss: 0.9185 - val_accuracy: 0.4773 - val_loss: 1.0225
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.5429 - loss: 0.9191 - val_accuracy: 0.4858 - val_loss: 1.0289
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5618 - loss: 0.8983
# Epoch 11: Лучшая точность этого запуска (0.4963) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5505 - loss: 0.9114 - val_accuracy: 0.4629 - val_loss: 1.0535
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 8 ---
#   Лучшая val_accuracy этого запуска: 0.49372
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №9/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - accuracy: 0.4276 - loss: 1.0726 - val_accuracy: 0.4484 - val_loss: 1.1160
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.4920 - loss: 1.0030 - val_accuracy: 0.4732 - val_loss: 1.0405
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5030 - loss: 0.9777 - val_accuracy: 0.4777 - val_loss: 1.0221
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.5122 - loss: 0.9659 - val_accuracy: 0.4709 - val_loss: 1.0211
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.5167 - loss: 0.9587 - val_accuracy: 0.4768 - val_loss: 1.0126
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5235 - loss: 0.9517 - val_accuracy: 0.4691 - val_loss: 1.0125
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.5304 - loss: 0.9438 - val_accuracy: 0.4820 - val_loss: 1.0061
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5362 - loss: 0.9353 - val_accuracy: 0.4739 - val_loss: 1.0149
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.5331 - loss: 0.9375 - val_accuracy: 0.4866 - val_loss: 1.0150
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.5435 - loss: 0.9272 - val_accuracy: 0.4802 - val_loss: 1.0244
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.5486 - loss: 0.9178 - val_accuracy: 0.4798 - val_loss: 1.0376
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - accuracy: 0.5511 - loss: 0.9112 - val_accuracy: 0.4568 - val_loss: 1.0642
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5637 - loss: 0.8876
# Epoch 13: Лучшая точность этого запуска (0.4866) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5567 - loss: 0.9051 - val_accuracy: 0.4405 - val_loss: 1.0891
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 9 ---
#   Лучшая val_accuracy этого запуска: 0.48199
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №10/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.4525 - loss: 1.0531 - val_accuracy: 0.4348 - val_loss: 1.1228
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.4936 - loss: 1.0066 - val_accuracy: 0.4455 - val_loss: 1.0814
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5088 - loss: 0.9788 - val_accuracy: 0.4611 - val_loss: 1.0482
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5179 - loss: 0.9646 - val_accuracy: 0.4673 - val_loss: 1.0387
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5231 - loss: 0.9560 - val_accuracy: 0.4766 - val_loss: 1.0241
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5336 - loss: 0.9438 - val_accuracy: 0.4328 - val_loss: 1.0543
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.5391 - loss: 0.9323 - val_accuracy: 0.4320 - val_loss: 1.0551
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.5448 - loss: 0.9230 - val_accuracy: 0.4535 - val_loss: 1.0467
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 298ms/step - accuracy: 0.5537 - loss: 0.9123 - val_accuracy: 0.4472 - val_loss: 1.0879
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5534 - loss: 0.9142 - val_accuracy: 0.4340 - val_loss: 1.1243
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5678 - loss: 0.8908
# Epoch 11: Лучшая точность этого запуска (0.4766) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.5612 - loss: 0.9026 - val_accuracy: 0.4151 - val_loss: 1.1879
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 10 ---
#   Лучшая val_accuracy этого запуска: 0.47658
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №11/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - accuracy: 0.4176 - loss: 1.0784 - val_accuracy: 0.4499 - val_loss: 1.0999
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.4973 - loss: 1.0002 - val_accuracy: 0.4439 - val_loss: 1.0742
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5136 - loss: 0.9741 - val_accuracy: 0.4476 - val_loss: 1.0641
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5199 - loss: 0.9678 - val_accuracy: 0.4788 - val_loss: 1.0258
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.5276 - loss: 0.9522 - val_accuracy: 0.4864 - val_loss: 1.0159
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5337 - loss: 0.9430 - val_accuracy: 0.4740 - val_loss: 1.0191
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5374 - loss: 0.9355 - val_accuracy: 0.4765 - val_loss: 1.0171
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5422 - loss: 0.9271 - val_accuracy: 0.4662 - val_loss: 1.0297
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 27s 543ms/step - accuracy: 0.5464 - loss: 0.9202 - val_accuracy: 0.4916 - val_loss: 1.0133
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.5487 - loss: 0.9146 - val_accuracy: 0.4756 - val_loss: 1.0470
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5493 - loss: 0.9122 - val_accuracy: 0.4901 - val_loss: 1.0203
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5513 - loss: 0.9083 - val_accuracy: 0.4771 - val_loss: 1.0341
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 327ms/step - accuracy: 0.5558 - loss: 0.9018 - val_accuracy: 0.4566 - val_loss: 1.0672
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.5609 - loss: 0.8933 - val_accuracy: 0.4507 - val_loss: 1.0854
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5728 - loss: 0.8754
# Epoch 15: Лучшая точность этого запуска (0.4916) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5623 - loss: 0.8924 - val_accuracy: 0.4457 - val_loss: 1.0942
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 11 ---
#   Лучшая val_accuracy этого запуска: 0.49157
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №12/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.4073 - loss: 1.1041 - val_accuracy: 0.3527 - val_loss: 1.1215
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.4834 - loss: 1.0217 - val_accuracy: 0.4196 - val_loss: 1.1143
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5047 - loss: 0.9859 - val_accuracy: 0.4419 - val_loss: 1.0774
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.5063 - loss: 0.9737 - val_accuracy: 0.4536 - val_loss: 1.0757
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5152 - loss: 0.9663 - val_accuracy: 0.4585 - val_loss: 1.0581
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.5170 - loss: 0.9621 - val_accuracy: 0.4613 - val_loss: 1.0552
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5227 - loss: 0.9547 - val_accuracy: 0.4675 - val_loss: 1.0435
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.5298 - loss: 0.9459 - val_accuracy: 0.4701 - val_loss: 1.0470
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.5335 - loss: 0.9450 - val_accuracy: 0.4509 - val_loss: 1.0562
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.5386 - loss: 0.9330 - val_accuracy: 0.4426 - val_loss: 1.0622
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 169ms/step - accuracy: 0.5458 - loss: 0.9239 - val_accuracy: 0.4117 - val_loss: 1.0799
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.5500 - loss: 0.9148 - val_accuracy: 0.4224 - val_loss: 1.0900
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5621 - loss: 0.8933
# Epoch 13: Лучшая точность этого запуска (0.4701) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.5534 - loss: 0.9102 - val_accuracy: 0.4089 - val_loss: 1.1086
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 12 ---
#   Лучшая val_accuracy этого запуска: 0.46752
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №13/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.4237 - loss: 1.0745 - val_accuracy: 0.4908 - val_loss: 1.0919
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4938 - loss: 1.0009 - val_accuracy: 0.4950 - val_loss: 1.0540
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5066 - loss: 0.9784 - val_accuracy: 0.4964 - val_loss: 1.0226
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.5144 - loss: 0.9678 - val_accuracy: 0.5016 - val_loss: 1.0082
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.5211 - loss: 0.9592 - val_accuracy: 0.4995 - val_loss: 0.9987
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5292 - loss: 0.9502 - val_accuracy: 0.5006 - val_loss: 0.9987
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5348 - loss: 0.9395 - val_accuracy: 0.4858 - val_loss: 1.0104
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5386 - loss: 0.9320 - val_accuracy: 0.4910 - val_loss: 1.0109
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.5434 - loss: 0.9246 - val_accuracy: 0.4625 - val_loss: 1.0387
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.5487 - loss: 0.9161 - val_accuracy: 0.4640 - val_loss: 1.0291
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5613 - loss: 0.8967
# Epoch 11: Лучшая точность этого запуска (0.5016) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5526 - loss: 0.9126 - val_accuracy: 0.4809 - val_loss: 1.0155
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 13 ---
#   Лучшая val_accuracy этого запуска: 0.50062
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №14/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 0.4043 - loss: 1.0929 - val_accuracy: 0.4675 - val_loss: 1.0906
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.4883 - loss: 1.0138 - val_accuracy: 0.4816 - val_loss: 1.0585
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.5067 - loss: 0.9792 - val_accuracy: 0.4757 - val_loss: 1.0363
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.5140 - loss: 0.9623 - val_accuracy: 0.4864 - val_loss: 1.0241
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5219 - loss: 0.9519 - val_accuracy: 0.4924 - val_loss: 1.0093
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.5254 - loss: 0.9432 - val_accuracy: 0.4861 - val_loss: 1.0184
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5351 - loss: 0.9330 - val_accuracy: 0.5015 - val_loss: 1.0159
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5401 - loss: 0.9268 - val_accuracy: 0.5019 - val_loss: 1.0179
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5445 - loss: 0.9243 - val_accuracy: 0.4965 - val_loss: 1.0372
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.5481 - loss: 0.9152 - val_accuracy: 0.4815 - val_loss: 1.0419
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5598 - loss: 0.8905
# Epoch 11: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #5...
# Epoch 11: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5528 - loss: 0.9066 - val_accuracy: 0.4782 - val_loss: 1.0471
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.5274 - loss: 0.9403 - val_accuracy: 0.5014 - val_loss: 1.0227
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.5308 - loss: 0.9380 - val_accuracy: 0.4995 - val_loss: 1.0230
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.5324 - loss: 0.9346 - val_accuracy: 0.4981 - val_loss: 1.0288
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.5351 - loss: 0.9319 - val_accuracy: 0.4943 - val_loss: 1.0358
# Epoch 16/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.5372 - loss: 0.9286 - val_accuracy: 0.4913 - val_loss: 1.0424
# Epoch 17/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5463 - loss: 0.9113
# Epoch 17: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #5...
# Epoch 17: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5404 - loss: 0.9260 - val_accuracy: 0.4901 - val_loss: 1.0482
# Epoch 18/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.5258 - loss: 0.9402 - val_accuracy: 0.5017 - val_loss: 1.0216
# Epoch 19/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5303 - loss: 0.9380 - val_accuracy: 0.4995 - val_loss: 1.0236
# Epoch 20/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.5329 - loss: 0.9345 - val_accuracy: 0.4972 - val_loss: 1.0274
# Epoch 20: early stopping
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 14 ---
#   Лучшая val_accuracy этого запуска: 0.49244
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №15/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 0.4280 - loss: 1.0756 - val_accuracy: 0.4590 - val_loss: 1.0782
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.4843 - loss: 1.0154 - val_accuracy: 0.4662 - val_loss: 1.0639
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.5040 - loss: 0.9827 - val_accuracy: 0.4619 - val_loss: 1.0796
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.5118 - loss: 0.9731 - val_accuracy: 0.4881 - val_loss: 1.0428
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.5178 - loss: 0.9616 - val_accuracy: 0.4891 - val_loss: 1.0303
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.5211 - loss: 0.9572 - val_accuracy: 0.4651 - val_loss: 1.0337
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5258 - loss: 0.9506 - val_accuracy: 0.4424 - val_loss: 1.0459
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.5301 - loss: 0.9427 - val_accuracy: 0.4312 - val_loss: 1.0592
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.5347 - loss: 0.9392 - val_accuracy: 0.4176 - val_loss: 1.0694
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.5411 - loss: 0.9256 - val_accuracy: 0.3953 - val_loss: 1.1070
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5569 - loss: 0.9033
# Epoch 11: Лучшая точность этого запуска (0.4891) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - accuracy: 0.5473 - loss: 0.9194 - val_accuracy: 0.3774 - val_loss: 1.1371
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 15 ---
#   Лучшая val_accuracy этого запуска: 0.48914
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №16/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.4400 - loss: 1.0603 - val_accuracy: 0.3510 - val_loss: 1.1453
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.4896 - loss: 1.0059 - val_accuracy: 0.4275 - val_loss: 1.1050
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - accuracy: 0.5052 - loss: 0.9769 - val_accuracy: 0.4465 - val_loss: 1.0488
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - accuracy: 0.5127 - loss: 0.9690 - val_accuracy: 0.4678 - val_loss: 1.0254
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5148 - loss: 0.9611 - val_accuracy: 0.4799 - val_loss: 1.0185
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5196 - loss: 0.9548 - val_accuracy: 0.4838 - val_loss: 1.0217
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.5267 - loss: 0.9477 - val_accuracy: 0.4689 - val_loss: 1.0260
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.5315 - loss: 0.9412 - val_accuracy: 0.4364 - val_loss: 1.0612
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.5353 - loss: 0.9341 - val_accuracy: 0.4249 - val_loss: 1.0638
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.5404 - loss: 0.9260 - val_accuracy: 0.4150 - val_loss: 1.0745
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5527 - loss: 0.9055
# Epoch 11: Лучшая точность этого запуска (0.4838) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.5436 - loss: 0.9222 - val_accuracy: 0.4109 - val_loss: 1.0786
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 16 ---
#   Лучшая val_accuracy этого запуска: 0.47994
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №17/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 0.4390 - loss: 1.0603 - val_accuracy: 0.4641 - val_loss: 1.1122
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.4900 - loss: 1.0073 - val_accuracy: 0.4527 - val_loss: 1.0867
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.5038 - loss: 0.9811 - val_accuracy: 0.4555 - val_loss: 1.0422
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.5117 - loss: 0.9674 - val_accuracy: 0.4588 - val_loss: 1.0280
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.5197 - loss: 0.9575 - val_accuracy: 0.4879 - val_loss: 1.0069
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5282 - loss: 0.9472 - val_accuracy: 0.4909 - val_loss: 1.0011
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.5346 - loss: 0.9375 - val_accuracy: 0.4833 - val_loss: 1.0094
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.5395 - loss: 0.9344 - val_accuracy: 0.4620 - val_loss: 1.0214
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.5457 - loss: 0.9242 - val_accuracy: 0.4508 - val_loss: 1.0267
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5502 - loss: 0.9173 - val_accuracy: 0.4274 - val_loss: 1.0473
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.5532 - loss: 0.9103 - val_accuracy: 0.4268 - val_loss: 1.0540
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5653 - loss: 0.8845
# Epoch 12: Лучшая точность этого запуска (0.4909) значительно хуже глобального рекорда (0.5120). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.5585 - loss: 0.9003 - val_accuracy: 0.4460 - val_loss: 1.0458
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 17 ---
#   Лучшая val_accuracy этого запуска: 0.49094
# Результат не превысил глобальный рекорд (0.51204).
#
# ========================= Начинаю запуск №18/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.4231 - loss: 1.0780 - val_accuracy: 0.4600 - val_loss: 1.1051
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.4897 - loss: 0.9997 - val_accuracy: 0.5084 - val_loss: 1.0533
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.5046 - loss: 0.9760 - val_accuracy: 0.5112 - val_loss: 1.0116
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.5126 - loss: 0.9652 - val_accuracy: 0.5088 - val_loss: 1.0018
# Epoch 5/150
# ...
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5621 - loss: 0.8885
# Epoch 11: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #5...
# Epoch 11: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5537 - loss: 0.9053 - val_accuracy: 0.4854 - val_loss: 1.0359
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5303 - loss: 0.9414 - val_accuracy: 0.4948 - val_loss: 1.0159
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5331 - loss: 0.9382 - val_accuracy: 0.4973 - val_loss: 1.0135
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5354 - loss: 0.9355 - val_accuracy: 0.4985 - val_loss: 1.0126
# Epoch 15/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - accuracy: 0.5368 - loss: 0.9329 - val_accuracy: 0.4979 - val_loss: 1.0144
# Epoch 16/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.5386 - loss: 0.9306 - val_accuracy: 0.4982 - val_loss: 1.0170
# Epoch 17/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5479 - loss: 0.9113
# Epoch 17: val_loss не улучшался 6 эпох. Восстанавливаю лучшие веса из эпохи #5...
# Epoch 17: Снижаю скорость обучения до 1e-03.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5409 - loss: 0.9282 - val_accuracy: 0.4986 - val_loss: 1.0173
# Epoch 18/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5305 - loss: 0.9413 - val_accuracy: 0.4948 - val_loss: 1.0155
# Epoch 19/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5336 - loss: 0.9380 - val_accuracy: 0.4958 - val_loss: 1.0132
# Epoch 20/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.5357 - loss: 0.9355 - val_accuracy: 0.4976 - val_loss: 1.0134
# Epoch 20: early stopping
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 43 ---
#   Лучшая val_accuracy этого запуска: 0.49504
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №44/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - accuracy: 0.4467 - loss: 1.0626 - val_accuracy: 0.4334 - val_loss: 1.0962
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.4956 - loss: 1.0041 - val_accuracy: 0.4559 - val_loss: 1.0698
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5104 - loss: 0.9735 - val_accuracy: 0.4721 - val_loss: 1.0287
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5157 - loss: 0.9626 - val_accuracy: 0.4517 - val_loss: 1.0476
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5226 - loss: 0.9566 - val_accuracy: 0.4489 - val_loss: 1.0314
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.5288 - loss: 0.9471 - val_accuracy: 0.4406 - val_loss: 1.0351
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.5367 - loss: 0.9390 - val_accuracy: 0.4043 - val_loss: 1.0542
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5406 - loss: 0.9306 - val_accuracy: 0.4225 - val_loss: 1.0438
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5524 - loss: 0.9103
# Epoch 9: Лучшая точность этого запуска (0.4721) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5455 - loss: 0.9249 - val_accuracy: 0.3888 - val_loss: 1.0972
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 44 ---
#   Лучшая val_accuracy этого запуска: 0.47207
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №45/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.4376 - loss: 1.0640 - val_accuracy: 0.3934 - val_loss: 1.1398
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.4957 - loss: 1.0042 - val_accuracy: 0.4593 - val_loss: 1.0583
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.5089 - loss: 0.9773 - val_accuracy: 0.4656 - val_loss: 1.0382
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5169 - loss: 0.9637 - val_accuracy: 0.4850 - val_loss: 1.0187
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5227 - loss: 0.9564 - val_accuracy: 0.4906 - val_loss: 1.0246
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5285 - loss: 0.9482 - val_accuracy: 0.4891 - val_loss: 1.0160
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5357 - loss: 0.9402 - val_accuracy: 0.4937 - val_loss: 1.0169
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5412 - loss: 0.9314 - val_accuracy: 0.4990 - val_loss: 1.0103
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.5469 - loss: 0.9225 - val_accuracy: 0.4847 - val_loss: 1.0153
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5501 - loss: 0.9180 - val_accuracy: 0.4821 - val_loss: 1.0172
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5523 - loss: 0.9130 - val_accuracy: 0.4738 - val_loss: 1.0193
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5558 - loss: 0.9058 - val_accuracy: 0.4677 - val_loss: 1.0291
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.5592 - loss: 0.8999 - val_accuracy: 0.4444 - val_loss: 1.0429
# Epoch 14/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5717 - loss: 0.8759
# Epoch 14: Лучшая точность этого запуска (0.4990) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5623 - loss: 0.8919 - val_accuracy: 0.4650 - val_loss: 1.0386
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 45 ---
#   Лучшая val_accuracy этого запуска: 0.49896
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №46/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - accuracy: 0.4211 - loss: 1.0786 - val_accuracy: 0.3872 - val_loss: 1.1020
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.4880 - loss: 1.0138 - val_accuracy: 0.4367 - val_loss: 1.1095
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5067 - loss: 0.9842 - val_accuracy: 0.4693 - val_loss: 1.0512
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5139 - loss: 0.9699 - val_accuracy: 0.4706 - val_loss: 1.0349
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5188 - loss: 0.9629 - val_accuracy: 0.4706 - val_loss: 1.0301
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5244 - loss: 0.9559 - val_accuracy: 0.4754 - val_loss: 1.0189
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.5292 - loss: 0.9485 - val_accuracy: 0.4596 - val_loss: 1.0289
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.5367 - loss: 0.9385 - val_accuracy: 0.4478 - val_loss: 1.0575
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5417 - loss: 0.9307 - val_accuracy: 0.4577 - val_loss: 1.0429
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5471 - loss: 0.9215 - val_accuracy: 0.4639 - val_loss: 1.0341
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5516 - loss: 0.9194 - val_accuracy: 0.4380 - val_loss: 1.0762
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5644 - loss: 0.8902
# Epoch 12: Лучшая точность этого запуска (0.4754) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5576 - loss: 0.9078 - val_accuracy: 0.4463 - val_loss: 1.0755
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 46 ---
#   Лучшая val_accuracy этого запуска: 0.47536
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №47/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.4403 - loss: 1.0647 - val_accuracy: 0.4516 - val_loss: 1.1033
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.4935 - loss: 1.0041 - val_accuracy: 0.4897 - val_loss: 1.0476
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5132 - loss: 0.9727 - val_accuracy: 0.4886 - val_loss: 1.0253
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5190 - loss: 0.9623 - val_accuracy: 0.4909 - val_loss: 1.0149
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5247 - loss: 0.9558 - val_accuracy: 0.4841 - val_loss: 1.0135
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.5300 - loss: 0.9482 - val_accuracy: 0.4748 - val_loss: 1.0130
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5329 - loss: 0.9414 - val_accuracy: 0.4596 - val_loss: 1.0242
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5377 - loss: 0.9317 - val_accuracy: 0.4534 - val_loss: 1.0485
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.5455 - loss: 0.9243 - val_accuracy: 0.4562 - val_loss: 1.0448
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5501 - loss: 0.9168 - val_accuracy: 0.4300 - val_loss: 1.0752
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5545 - loss: 0.9106 - val_accuracy: 0.4352 - val_loss: 1.0919
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5661 - loss: 0.8891
# Epoch 12: Лучшая точность этого запуска (0.4909) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.5591 - loss: 0.9035 - val_accuracy: 0.4291 - val_loss: 1.1085
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 47 ---
#   Лучшая val_accuracy этого запуска: 0.47477
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №48/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - accuracy: 0.4401 - loss: 1.0638 - val_accuracy: 0.4154 - val_loss: 1.0949
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.4945 - loss: 1.0065 - val_accuracy: 0.4723 - val_loss: 1.0689
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5049 - loss: 0.9891 - val_accuracy: 0.4860 - val_loss: 1.0395
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5142 - loss: 0.9710 - val_accuracy: 0.4712 - val_loss: 1.0332
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5215 - loss: 0.9612 - val_accuracy: 0.4739 - val_loss: 1.0245
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.5266 - loss: 0.9541 - val_accuracy: 0.4805 - val_loss: 1.0135
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.5324 - loss: 0.9464 - val_accuracy: 0.4713 - val_loss: 1.0171
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5393 - loss: 0.9357 - val_accuracy: 0.4718 - val_loss: 1.0162
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5449 - loss: 0.9313 - val_accuracy: 0.4734 - val_loss: 1.0203
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5515 - loss: 0.9233 - val_accuracy: 0.4619 - val_loss: 1.0381
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5534 - loss: 0.9148 - val_accuracy: 0.4329 - val_loss: 1.0589
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5646 - loss: 0.8918
# Epoch 12: Лучшая точность этого запуска (0.4860) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.5585 - loss: 0.9056 - val_accuracy: 0.4308 - val_loss: 1.0944
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 48 ---
#   Лучшая val_accuracy этого запуска: 0.48046
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №49/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 110ms/step - accuracy: 0.4167 - loss: 1.0976 - val_accuracy: 0.4286 - val_loss: 1.1060
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.4830 - loss: 1.0122 - val_accuracy: 0.4706 - val_loss: 1.0689
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5026 - loss: 0.9856 - val_accuracy: 0.4861 - val_loss: 1.0282
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.5108 - loss: 0.9684 - val_accuracy: 0.4842 - val_loss: 1.0124
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.5169 - loss: 0.9608 - val_accuracy: 0.4657 - val_loss: 1.0149
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5226 - loss: 0.9536 - val_accuracy: 0.4721 - val_loss: 1.0117
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5292 - loss: 0.9466 - val_accuracy: 0.4703 - val_loss: 1.0154
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.5343 - loss: 0.9382 - val_accuracy: 0.4498 - val_loss: 1.0302
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5386 - loss: 0.9314 - val_accuracy: 0.4336 - val_loss: 1.0590
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5422 - loss: 0.9312 - val_accuracy: 0.4102 - val_loss: 1.0714
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.5453 - loss: 0.9199 - val_accuracy: 0.3982 - val_loss: 1.1035
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5566 - loss: 0.8972
# Epoch 12: Лучшая точность этого запуска (0.4861) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.5505 - loss: 0.9117 - val_accuracy: 0.3983 - val_loss: 1.1090
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 49 ---
#   Лучшая val_accuracy этого запуска: 0.47207
# Результат не превысил глобальный рекорд (0.51384).
#
# ========================= Начинаю запуск №50/50 =========================
# Epoch 1/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - accuracy: 0.4160 - loss: 1.0828 - val_accuracy: 0.4566 - val_loss: 1.0666
# Epoch 2/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - accuracy: 0.4947 - loss: 1.0056 - val_accuracy: 0.4887 - val_loss: 1.0405
# Epoch 3/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.5110 - loss: 0.9805 - val_accuracy: 0.4772 - val_loss: 1.0199
# Epoch 4/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5166 - loss: 0.9674 - val_accuracy: 0.4849 - val_loss: 1.0186
# Epoch 5/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5235 - loss: 0.9586 - val_accuracy: 0.4871 - val_loss: 1.0184
# Epoch 6/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5270 - loss: 0.9517 - val_accuracy: 0.4910 - val_loss: 1.0095
# Epoch 7/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.5302 - loss: 0.9456 - val_accuracy: 0.4996 - val_loss: 1.0047
# Epoch 8/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - accuracy: 0.5350 - loss: 0.9369 - val_accuracy: 0.4999 - val_loss: 1.0089
# Epoch 9/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.5387 - loss: 0.9311 - val_accuracy: 0.4984 - val_loss: 1.0145
# Epoch 10/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.5442 - loss: 0.9222 - val_accuracy: 0.4953 - val_loss: 1.0219
# Epoch 11/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5480 - loss: 0.9171 - val_accuracy: 0.4822 - val_loss: 1.0469
# Epoch 12/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.5527 - loss: 0.9127 - val_accuracy: 0.4691 - val_loss: 1.0597
# Epoch 13/150
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5643 - loss: 0.8894
# Epoch 13: Лучшая точность этого запуска (0.4999) значительно хуже глобального рекорда (0.5138). Прерываю.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.5555 - loss: 0.9046 - val_accuracy: 0.4648 - val_loss: 1.0686
# Загружаю лучшие веса, найденные в этом запуске...
#
# --- Результаты запуска 50 ---
#   Лучшая val_accuracy этого запуска: 0.49962
# Результат не превысил глобальный рекорд (0.51384).
#
# ✅ Все запуски завершены. Финальная лучшая модель сохранена в: /home/restorator/trader_test/2_results/models/universal_60_10_v1_corr_threshold_75/model.keras

# %%
# !python -m _tools.train_universal_lstm \
    --model_name "{MODEL_NAME}" \
    --data_model_name "{DATA_SOURCE_MODEL}" \
    --use_gpu \
    --batch_size 4096 \
    --lr 1e-2 \
    --l2_reg 2.2e-8 \
    --verbose 1 \
    --leaky_relu_negative_slope 0.062 \
    --runs 30

# %% [markdown]
# 10. Сравнительный анализ крутизны ланшафта потерь в окресности решения (среднего значения модели на train)

# %%
MODEL_NAME = "universal_60_10_v1_corr_threshold_90"  # Имя вашей лучшей модели
TICKER = "YKEN"  # Тикер для теста

# !python -m _tools.backtester \
    --model_name "{MODEL_NAME}" \
    --ticker "{TICKER}"
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760555941.830407  877262 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760555943.056353  877262 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# --- 📈 Запуск бектеста для модели 'universal_60_10_v1_corr_threshold_90' на тикере 'YKEN' ---
# Загрузка артефактов...
# ✅ Артефакты загружены. Lookback: 60, Признаков: 109
# Загрузка данных для тикера из /home/restorator/trader_test/2_results/features_processed/YKEN.csv...
# Подготовка 184 строк данных для модели...
# Получение предсказаний модели...
# Создание графика...
# ✅ График бектеста сохранен в: /home/restorator/trader_test/2_results/reports/backtest_universal_60_10_v1_corr_threshold_90_YKEN.png
#
# --- 📊 Базовая статистика ---
# Количество сигналов 'Buy': 4
# Количество сигналов 'Sell': 121
# Доходность 'Купи и держи' за период: -5.88%

# %%
# !python -m _tools.compare_model_sharpness \
    --model_prefix "{MODEL_NAME_PREFIX}" \
    --batch_size 16384 \
    --n_probes 100 \
    --noise_scale 1e-0
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760602169.495873  144405 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760602170.883758  144405 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# --- Сравнительный детерминированный анализ резкости для моделей с префиксом: 'universal_60_10_v1' ---
# Найдено 4 моделей для сравнения.
# Используются данные, соответствующие каждой модели.
# Анализ моделей: 100%|█████████████████████████████| 4/4 [05:10<00:00, 77.61s/it]
#
# --- 📊 Итоговая таблица сравнения (детерминированная) ---
#                                        min_loss  accuracy  sharpness
# model_name
# universal_60_10_v1_corr_threshold_100    0.9920    0.5139     0.8460
# universal_60_10_v1_corr_threshold_50     1.1068    0.4171     0.9229
# universal_60_10_v1_corr_threshold_75     0.9901    0.5138     0.7829
# universal_60_10_v1_corr_threshold_90     0.9872    0.5161     0.8680
#
# --- 🏆 Рекомендации ---
# Модель с самым низким loss (лучшее качество): universal_60_10_v1_corr_threshold_90 (0.9872)
# Модель с самой высокой точностью (best accuracy): universal_60_10_v1_corr_threshold_90 (0.5161)
# Модель с наименьшей резкостью (самая устойчивая): universal_60_10_v1_corr_threshold_75 (0.7829)

# %% [markdown]
# 11. Расчет ландшафта потерь (loss) модели и построение тепловых карт двумерных проекций модели

# %%
# !python -m _tools.calculate_landscape \
    --model_name "{MODEL_NAME}" \
    --data_model_name "{DATA_SOURCE_MODEL}" \
    --model_filename model.keras \
    --scale 1 \
    --points 14 \
    --batch_size 16384 \
    --num_images 1
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760553515.310887  857493 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760553516.493180  857493 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# --- Расчет ландшафта потерь для модели: model.keras ---
# --- Используются данные от: universal_60_10_v1_corr_threshold_75 ---
# ❌ Ошибка при загрузке артефактов: STACK_GLOBAL requires str

# %%
# !python -m _tools.plot_landscape_from_data \
    --model_name "universal_60_10_v4_lrelu_alpha_4" \
    --model_filename model.keras \
    --vmax 1 \
    --plot_type 2d
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758742230.210234  787253 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758742231.385963  787253 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# --- ОТРИСОВКА (2d) ландшафта для модели 'universal_60_10_v1_60_features_v2' ---
# Найдено 3 файлов с данными. Начинаю отрисовку...
#
# ✅ Отрисовка завершена. 3 изображений сохранены в: /home/restorator/trader_test/2_results/reports/landscape_plots_universal_60_10_v1_60_features_v2
